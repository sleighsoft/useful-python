# %%
import numpy as np

import polar_histogram as ph

# %%
# Random data (ignore)
np.random.seed(0)
randomNums = np.random.normal(180, 180, size=100000)
randomInts = np.round(randomNums)
randomInts = randomInts[np.where(0 <= randomInts)]
data = randomInts[np.where(randomInts < 360)]

# Run it
figure, axes = ph.polar_histogram(data)
